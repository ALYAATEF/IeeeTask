# %% [markdown]
# #### Task1
# ##### what are outliers?
# An outlier is an unusually large or small observation.
# ##### how does it affect data?
# Outliers can have a disproportionate effect on statistical results, such as the mean, which can result in misleading interpretations.

# %% [markdown]
# #### Task2
# ##### what are the mean, median, and mode?
# * Mean is the average of all values in a set.It’s equal to the sum of all the values in the data set divided by the number of values in the data set.
# * median is the middle number in a set of numbers sorted by size
# * mode is the most frequent score in the data set.
# ##### if their order is (Mean>Median>Mode)
# * so the data is right skewed

# %% [markdown]
# #### Task3
# ##### what is the propability of tossing a fair coin 10 times and getting heads 9 times?
# P(x=9)=(10C9)/2**10 =5/512

# %% [markdown]
# #### Task4.1
#  * https://codeforces.com/contest/791/problem/A

# %%
print("Input the value of a & b")
a,b = map(int, input().split())
s=0
while a<=b :
    s+=1
    if a<=b:
        a*=3
        b*=2
    else:
        break
print(s)
# Out:
# Input the value of a & b
# 4 9
# 3

# %% [markdown]
# #### Task4.2
# * https://codeforces.com/contest/58/problem/A

# %%
x= list('hello') 
y=list(input("Enter the word "))
if(all(i in y for i in x)) and (len(x)<len(y)) :
    flag = 'Yes'
else:
    flag = 'No'
print(flag)
# Out:
# Enter the word ahhellllloou
# Yes
